# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Fuel resources data

# %%
############################################
#NATURAL GAS PRICES
############################################
cd = os.getcwd()
extra_path = 'Fuels_data.csv'
path_fuels = os.path.join(cd, extra_path)

df = pd.read_csv('Fuels_data.csv')
# Plotting the values for each Time_Index of the 3 columns (CT_NG, ME_NG, MA_NG)
plt.figure(figsize=(10, 6))

plt.plot(df['Time_Index'], df['CT_NG'], label='CT_NG', color='blue')
plt.plot(df['Time_Index'], df['ME_NG'], label='ME_NG', color='green')
plt.plot(df['Time_Index'], df['MA_NG'], label='MA_NG', color='red')

plt.title('Natural Gas Prices Over Time')
plt.xlabel('Time Index')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ## Capacity factors

# %%
############################################
#CAPACITY FACTORS
############################################
cd = os.getcwd()
extra_path_CF = 'Generators_variability.csv'
path_CF = os.path.join(cd, extra_path_CF)

df_CF = pd.read_csv(path_CF)
df_CF.plot(x='Time_Index', ylabel='Capacity factors')
# Out:
# <Axes: xlabel='Time_Index', ylabel='Capacity factors'>

# %%
df_CF.plot(x='Time_Index', kind='box', figsize=(15, 5),ylabel= 'Capacity factor')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Demand data

# %%
cd = os.getcwd()
extra_path_D = 'Demand_data.csv'
path_D = os.path.join(cd, extra_path_D)

# %%
df_D = pd.read_csv(path_D)
df_D_Zones= df_D[['Time_Index', 'Demand_MW_z1', 'Demand_MW_z2', 'Demand_MW_z3']].copy(deep=True)
display(df_D)
# Out:
#          Voll  Demand_Segment  Cost_of_Demand_Curtailment_per_MW  \
# 0     50000.0             1.0                               1.00
# 1         NaN             2.0                               0.90
# 2         NaN             3.0                               0.55
# 3         NaN             4.0                               0.20
# 4         NaN             NaN                                NaN
# ...       ...             ...                                ...
# 8755      NaN             NaN                                NaN
# 8756      NaN             NaN                                NaN
# 8757      NaN             NaN                                NaN
# 8758      NaN             NaN                                NaN
# 8759      NaN             NaN                                NaN
#
#       Max_Demand_Curtailment   $/MWh  Rep_Periods  Timesteps_per_Rep_Period  \
# 0                      1.000  2000.0          1.0                    8760.0
# ...

# %%
df_D.plot(x='Time_Index', y='Demand_MW_z1', ylabel= "Electricity Demand [MWh]", figsize=(15,5))
# Out:
# <Axes: xlabel='Time_Index', ylabel='Electricity Demand [MWh]'>
