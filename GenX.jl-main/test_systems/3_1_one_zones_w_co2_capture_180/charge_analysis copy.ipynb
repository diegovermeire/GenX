# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
charge_HO = pd.read_csv(r"C:\Users\Diego\GenX\GenX.jl-main\test_systems\3_1_one_zones_w_co2_capture_180\results_78\power_balance.csv")
charge_HE = pd.read_csv(r"C:\Users\Diego\GenX\GenX.jl-main\test_systems\3_1_one_zones_w_co2_capture_180\results_79\power_balance.csv")

# %%
charge_HO[charge_HO["Storage_Discharge"] > 200]
# Out:
#     BalanceComponent    Generation  Storage_Discharge  Storage_Charge  \
# 1          AnnualSum  2.004194e+06        9767.335180   -1.153986e+04
# 35               t34  1.610983e+04         288.827127   -7.384561e-13
# 36               t35  1.610983e+04         457.320127   -8.575117e-13
# 37               t36  1.610983e+04         557.020127   -7.179070e-13
# 38               t37  1.610983e+04         419.434127   -7.197126e-13
# 57               t56  1.610983e+04         457.171127   -6.879286e-10
# 58               t57  1.610983e+04         469.171127   -7.128705e-10
# 59               t58  1.610983e+04         469.171127   -9.217332e-10
# 92               t91  7.539400e+03         273.258084   -5.056580e+02
# 93               t92  7.539400e+03         427.988929   -6.603888e+02
# 94               t93  7.539400e+03         272.538630   -9.489385e+02
# 95               t94  7.539400e+03         272.538630   -9.489385e+02
# ...

# %%
charge_HE[charge_HE["Storage_Discharge"] > 200]
# Out:
#    BalanceComponent    Generation  Storage_Discharge  Storage_Charge  \
# 1         AnnualSum  2.004193e+06        9766.734362   -1.153915e+04
# 35              t34  1.610980e+04         288.810923   -1.920762e-15
# 36              t35  1.610980e+04         457.305994   -1.956760e-15
# 37              t36  1.610980e+04         557.006664   -1.997254e-15
# 38              t37  1.610980e+04         419.419316   -2.074172e-15
# 57              t56  1.610980e+04         457.200000   -2.064077e-12
# 58              t57  1.610980e+04         469.200000   -1.575279e-12
# 75              t74  7.539386e+03         350.305395   -5.826918e+02
# 76              t75  7.539386e+03         272.545386   -9.489318e+02
# 77              t76  7.539386e+03         205.045386   -1.016432e+03
# 78              t77  7.539386e+03         618.045386   -6.034318e+02
# 79              t78  7.951523e+03        1221.477173   -6.493605e-17
#
# ...
