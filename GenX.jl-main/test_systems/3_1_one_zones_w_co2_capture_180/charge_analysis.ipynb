# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
charge_HO = pd.read_csv(r"C:\Users\Diego\GenX\GenX.jl-main\test_systems\3_1_one_zones_w_co2_capture\results_56\power_balance.csv")
charge_HE = pd.read_csv(r"C:\Users\Diego\GenX\GenX.jl-main\test_systems\3_1_one_zones_w_co2_capture\results_57\power_balance.csv")

# %%
charge_HO[charge_HO["Storage_State_of_Charge"] > 6600]
# Out:
#      BalanceComponent    Generation  Storage_Discharge  Storage_Charge  \
# 1           AnnualSum  8.233375e+07       6.158371e+05  -727595.809756
# 877              t876  1.539867e+04       8.961301e-12     -488.666692
# 1329            t1328  7.252679e+03       2.590000e+02     -980.678747
#
#       Flexible_Demand_Defer  Flexible_Demand_Stasify  Demand_Response  \
# 1                       0.0                      0.0     3.924793e+02
# 877                     0.0                      0.0     5.768357e-15
# 1329                    0.0                      0.0     7.270281e-16
#
#       Nonserved_Energy  Transmission_NetExport  Transmission_Losses  \
# 1         9.667614e-13                     0.0                  0.0
# 877       7.266460e-16                     0.0                  0.0
# 1329      1.001326e-16                     0.0                  0.0
#
#             Demand  Storage_State_of_Charge
# 1    -8.222238e+07             2.941243e+07
# ...

# %%
charge_HE[charge_HE["Storage_State_of_Charge"] > 6600]
# Out:
#      BalanceComponent    Generation  Storage_Discharge  Storage_Charge  \
# 1           AnnualSum  8.233302e+07       6.118422e+05  -722875.998588
# 859              t858  1.509434e+04       9.374915e-11     -184.336861
# 1085            t1084  7.250584e+03       2.590000e+02     -978.583781
#
#       Flexible_Demand_Defer  Flexible_Demand_Stasify  Demand_Response  \
# 1                       0.0                      0.0     3.924793e+02
# 859                     0.0                      0.0     4.083463e-14
# 1085                    0.0                      0.0     4.884463e-15
#
#       Nonserved_Energy  Transmission_NetExport  Transmission_Losses  \
# 1         1.031539e-11                     0.0                  0.0
# 859       6.116695e-15                     0.0                  0.0
# 1085      6.476893e-16                     0.0                  0.0
#
#             Demand  Storage_State_of_Charge
# 1    -8.222238e+07             2.963247e+07
# ...
